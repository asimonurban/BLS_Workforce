# %% [markdown]
# # Python User Group Training: Requests and Pandas

# %% [markdown]
# ## Do Now:
#
# 1. Go on your web browser and enter this url - ""
# 2. Go to "File", and then select "Make a Copy"
# 3. Rename file to something unique
# 4. After completing steps 1 -3, write down a common data skill you often use at your current role and a data skill you wish you used more/had.

# %% [markdown]
# ## Objective:
# The objective today is to go over the fundamentals of Request and Pandas.

# %% [markdown]
# ## Proving Behavior:
#
# 1. Be able to use Requests to execute a simple GET/POST requests and understand when necessary to do one or the other.
# 2. Load a dataset using Pandas and process/clean a data in prepration for analysis.

# %% [markdown]
# ## Purpose:
#
# 1. Python is a general purpose programming lanaguage and because of that it has a multitude of functions to interact with other systems really well
# 2. This allows Python to be an excellent langauge for web scraping and API pulls.
# 3. The beauty of Python is that it can collect data in this way and in the same script, clean the data and conduct statistical analysis.

# %% [markdown]
# ## Requests: What is Requests?

# %%
import requests

# %% [markdown]
# ## Requests: GET

# %%
url = "https://educationdata.urban.org/api/v1/school-districts/ccd/directory/2013/"
response = requests.get(url)
response.text
# Out:
# '{"count":18785,"next":"https://educationdata.urban.org/api/v1/school-districts/ccd/directory/2013/?page=2","previous":null,"results":[{"year":2013,"leaid":"0100002","lea_name":"ALABAMA YOUTH SERVICES","fips":1,"state_leaid":"210","street_mailing":"P O BOX 66","city_mailing":"MT MEIGS","state_mailing":"AL","zip_mailing":"36057","zip4_mailing":"0066","street_location":"1000 INDUSTRIAL SCHOOL ROAD","city_location":"MT. MEIGS","state_location":"AL","zip_location":"36057","zip4_location":"0066","phone":"3342153850","latitude":32.377,"longitude":-86.083,"urban_centric_locale":21,"cbsa":33860,"cbsa_type":1,"csa":-2,"cmsa":null,"necta":null,"county_code":"1101","county_name":"MONTGOMERY COUNTY","congress_district_id":103,"bureau_indian_education":0,"supervisory_union_number":"000","agency_type":1,"boundary_change_indicator":1,"agency_charter_indicator":3,"lowest_grade_offered":3,"highest_grade_offered":12,"number_of_schools":7,"enrollment":-1,"spec_ed_students":45,"english_language_learners
# ...

# %% [markdown]
# ## Requests: POST

# %%
# Set up API Portal 
### First, we define the url provided from CE and then we enter our authorization code
url = 'https://credentialengine.org/assistant/search/ctdl'
headers={'Authorization': 'ApiToken 7600d3fc-72da-4427-8bd7-9b3286d2f4b8'}
task = {"Query": {"@type": "ceterms:Certification"}, "Skip": 0, "Take": 100}
resp = requests.post(url, json=task, headers  = headers)
resp.text
# Out:
# '{"data":[{"@id":"https://credentialengineregistry.org/resources/ce-3877cdec-09b6-45df-814f-ede85c023858","@type":"ceterms:Certification","ceterms:ctid":"ce-3877cdec-09b6-45df-814f-ede85c023858","ceterms:name":{"en":"CompTIA A+"},"ceterms:image":"https://certification.comptia.org/UI/Assets/siteIcons/logoAPlus.svg","ceterms:naics":["519","541511","541512"],"ceterms:ownedBy":["https://credentialengineregistry.org/graph/ce-186FBC60-47E3-4616-B160-72CAC9E78F54"],"ceterms:renewal":[{"@type":"ceterms:ConditionProfile","ceterms:name":{"en":"CompTIA A+ Renewal"},"ceterms:assertedBy":["https://credentialengineregistry.org/graph/ce-186FBC60-47E3-4616-B160-72CAC9E78F54"],"ceterms:description":{"en":"Your CompTIA A+ certification is good for three years from the day of your exam. The CE program allows you to extend your certification in three-year intervals through activities and training that relate to the content of your certification. Like A+ itself, CompTIA A+ ce also carries globally-recogn
# ...

# %% [markdown]
# ## Why Pandas?

# %% [markdown]
# ### Pandas: How to begin data analysis in Python
#
# 1. Python has a variety of built in functions - but data anlaysis requires additional features.
# 2. Pandas was built to work with popular Python features and be a comprehensive data analysis package
# 3. Pandas is the go-to data analysis and machine learning
#
#
# | Pandas    | Stata       |
# |-----------|-------------|
# | DataFrame | data set    |
# | column    | variable    |
# | row       | observation |
# | groupby   | bysort      |
# | NaN       | .           |

# %%
import pandas as pd

# %% [markdown]
# ## Pandas: DataFrame

# %% [markdown]
# The DataFrame is the main contribution of Pandas. The DataFrame is a 2-dimensional labeled structure with columns and rows. The columns and the rows represent one dimension each. The DataFrame is anaglous to the R DataFrame and Stata Dataset and the Excel spreadsheet. Or put in more technical terms, the DataFrame is a tabular datastructure. The code below defines a DataFrame and then prints it out to view:

# %%
d = pd.DataFrame({'one': [1., 2., 3., 4.],
     'two': [4., 3., 2., 1.]})
d
# Out:
#    one  two
# 0  1.0  4.0
# 1  2.0  3.0
# 2  3.0  2.0
# 3  4.0  1.0

# %% [markdown]
# "d" is the name of our DataFrame and it has two columns, one and two, and four rows, 0-3. (Python is 0 indexed, meaning it counts from 0...1...2...and so on.)
#
# Each datapoint can be referenced through its Index (which corresponds to its row, the far most left value) and the column signifies what the value means. We can call a single Pandas column with this command:

# %%
(d['one'])
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# Name: one, dtype: float64

# %% [markdown]
# The values on the left represent the Index we saw earlier. Notice: A Python's column's type is itself a Pandas object, the Series. More on this obect below.

# %% [markdown]
# ## Pandas:  Column (Series)

# %% [markdown]
# A Series ia one-dimensional indexed array that can contain any Python data type. To create a Series you use the function:

# %%
d['one']
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# Name: one, dtype: float64

# %%
d['one'] = d['one']*2
print("This is a Series multipled by two")
print(d['one'])
# Out:
# This is a Series multipled by two
# 0     4.0
# 1     8.0
# 2    12.0
# 3    16.0
# Name: one, dtype: float64

# %%
## In the space below, subtract the column "one" by 2

# %% [markdown]
# ## Pandas: Row (Index)

# %% [markdown]
# Both the Series and the DataFrame have an index that signifies order and allows for referencing specific points. The Index itself is an object - though by itself it holds little purpose.

# %%
d
# Out:
#     one  two
# 0   4.0  4.0
# 1   8.0  3.0
# 2  12.0  2.0
# 3  16.0  1.0

# %% [markdown]
# ## Pandas: Read various data types (read_csv, read_stata…)

# %% [markdown]
# Pandas can read muliple file types and convert to a DataFrame. All data reading will be in the format : pd.read_(DATA_FORMAT)('FILE_LOCATION').
#
# The allowed dataformats are:
# 1. DTA (read_stata)
# 2. XLSX (read_excel)
# 3. CSV (read_csv)
# 4. SAS (read_sas)
# 5. JSON (read_json)
#
# Let's take a look at an example

# %%
# The code below reads the file linked: 
url = "https://ui-spark-data-public.s3.amazonaws.com/lodes/summarized-files/Tract_level/fed_jobs/rac_all_fed_tract_level.csv"
pd.read_csv(url)
# Out:
#         year  st         stname    cty                    ctyname  \
# 0       2011   1        Alabama   1125      Tuscaloosa County, AL
# 1       2011   5       Arkansas   5083           Logan County, AR
# 2       2014   6     California   6019          Fresno County, CA
# 3       2013   6     California   6037     Los Angeles County, CA
# 4       2010   6     California   6037     Los Angeles County, CA
# 5       2012   6     California   6037     Los Angeles County, CA
# 6       2010   6     California   6037     Los Angeles County, CA
# 7       2013   6     California   6041           Marin County, CA
# 8       2012   6     California   6065       Riverside County, CA
# 9       2010   6     California   6067      Sacramento County, CA
# 10      2011   6     California   6071  San Bernardino County, CA
# 11      2010   6     California   6073       San Diego County, CA
# 12      2015   8       Colorado   8077            Mesa County, CO
# ...

# %%
# We'll need to assign the dataframe, so the program stores it.
df = pd.read_csv(url)

# %%
# Load this dataset with what you know about importing datasets using Pandas
url = "http://lmsresources.labormarketinfo.com/library/press/laus.xlsx"

# %% [markdown]
# ## Pandas: Exporting Data

# %%
df.to_csv('export.csv')

# %%
## In the line below, export file to a stata file

# %% [markdown]
# ## Pandas: Basic Viewing

# %%
df

# %%
df.head()

# %%
df.tail()

# %%
df.head(2)

# %%
# How would you get the last two observations of the dataframe?

# %% [markdown]
# ### Subset Dataframe: "locate" method
#
# DataFrame.loc
# - Label-based: Access a group of rows and columns by label(s) or a boolean array.
#
# DataFrame.iloc
# - Integer-based: Access a group of rows and columns by integer position(s).
#
#
# ##### Order of the indexes/labels inside the brackets obviously matters!
#
# dat.loc[0, 'year']
#
# - Seperated by comma
# - The first index/label(before comma): row(s) that we want to retrieve.
# - The second index/label(after comma): column(s) we want to retrieve. Optional, without a second index, iloc/loc will retrieve all columns by default.
# - Retrieve all rows but selected columns: use Colon(:) before comma to represent all columns, e.g. dat.loc[:, ['year', 'c000']]
#
#
# Most common inputs in the bracket []:
# - A single label/index, e.g., 'year'
# - A list of labels/indexes, e.g. ['year', 'stname', 'ctyname'] or [0, 5, 9]
# - A slice object with labels/indexes, e.g. 'year':'c000', 0:9

# %%
#A single label for row and column
dat.iloc[0]   #return a series

# %%
#A list of labels/indexes
dat.iloc[[0, 3, 7]]

# %%
#A slice object with labels/indexes
dat.iloc[0:5]

# %%
#A list of labels for rows and columns
dat.loc[0:6, ['year', 'stname', 'trctname', 'c000']]   

# note that 0:6 is interpreted as a label of the index, but not as an integer position along the index)

# %% [markdown]
# ## Slicing based on condition values

# %%
df.loc[df['c000'] == 50, 'c000_temp'] = 10000

# %% [markdown]
# ## Pandas: Summarizing dataframes

# %%
df.describe()

# %%
df.info()

# %%
df.dtypes

# %% [markdown]
# ## Pandas: Creating a new variable

# %%
df['7'] = 7
df.head()

# %%
# create a variable called string and give it a value of cat

# %% [markdown]
# ## Pandas: Creating a new variable with simple commands

# %%
df.head()
# Out:
#    year  st      stname   cty                 ctyname        trct  \
# 0    24   1     Alabama  1125   Tuscaloosa County, AL  1125012405
# 1    24   5    Arkansas  5083        Logan County, AR  5083950500
# 2  2018   6  California  6019       Fresno County, CA  6019005409
# 3  2017   6  California  6037  Los Angeles County, CA  6037127520
# 4  2014   6  California  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02  ...   cr05  cr07  ct01  ct02  \
# 0    124.05 (Tuscaloosa, AL)    50     8    34  ...      0     1    49     1
# 1           9505 (Logan, AR)    11     1     9  ...      0     0    11     0
# 2         54.09 (Fresno, CA)    29     7    16  ...      0     7    20     9
# 3  1275.20 (Los Angeles, CA)     4     0     4  ...      0     2     2     2
# 4     3109 (Los Angeles, CA)    15     0    12  ...      0     0    11     4
#
#    cd01  cd02  cd03  cd04  cs01  cs02
# 0     0     2    30    10    16    34
# ...

# %%
df['new_value'] = df['c000'] - (0.1 * df['ca01']) 
df.head()
# Out:
#    year  st      stname   cty                 ctyname        trct  \
# 0    24   1     Alabama  1125   Tuscaloosa County, AL  1125012405
# 1    24   5    Arkansas  5083        Logan County, AR  5083950500
# 2  2018   6  California  6019       Fresno County, CA  6019005409
# 3  2017   6  California  6037  Los Angeles County, CA  6037127520
# 4  2014   6  California  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02    ...      ct01  ct02  cd01  \
# 0    124.05 (Tuscaloosa, AL)    50     8    34    ...        49     1     0
# 1           9505 (Logan, AR)    11     1     9    ...        11     0     1
# 2         54.09 (Fresno, CA)    29     7    16    ...        20     9     1
# 3  1275.20 (Los Angeles, CA)     4     0     4    ...         2     2     0
# 4     3109 (Los Angeles, CA)    15     0    12    ...        11     4     0
#
#    cd02  cd03  cd04  cs01  cs02  new value  new_value
# 0     2    30    10    16    34       49.2       49.2
# ...

# %% [markdown]
# ### Pandas: Replacing a variable

# %%
df['new_value'] = df['new_value'] - 100
df.head()
# Out:
#    year  st      stname   cty                 ctyname        trct  \
# 0    24   1     Alabama  1125   Tuscaloosa County, AL  1125012405
# 1    24   5    Arkansas  5083        Logan County, AR  5083950500
# 2  2018   6  California  6019       Fresno County, CA  6019005409
# 3  2017   6  California  6037  Los Angeles County, CA  6037127520
# 4  2014   6  California  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02    ...      ct01  ct02  cd01  \
# 0    124.05 (Tuscaloosa, AL)    50     8    34    ...        49     1     0
# 1           9505 (Logan, AR)    11     1     9    ...        11     0     1
# 2         54.09 (Fresno, CA)    29     7    16    ...        20     9     1
# 3  1275.20 (Los Angeles, CA)     4     0     4    ...         2     2     0
# 4     3109 (Los Angeles, CA)    15     0    12    ...        11     4     0
#
#    cd02  cd03  cd04  cs01  cs02  new value  new_value
# 0     2    30    10    16    34       49.2      -50.8
# ...

# %%
# replace the value of string with dog

# %% [markdown]
# ## Pandas: Replacing values in a variable

# %%
df['c000'] = df['c000'].replace(50, 0)
df.head()
# Out:
#    year  st      stname   cty                 ctyname        trct  \
# 0    24   1     Alabama  1125   Tuscaloosa County, AL  1125012405
# 1    24   5    Arkansas  5083        Logan County, AR  5083950500
# 2  2018   6  California  6019       Fresno County, CA  6019005409
# 3  2017   6  California  6037  Los Angeles County, CA  6037127520
# 4  2014   6  California  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02    ...      ct01  ct02  cd01  \
# 0    124.05 (Tuscaloosa, AL)     0     8    34    ...        49     1     0
# 1           9505 (Logan, AR)    11     1     9    ...        11     0     1
# 2         54.09 (Fresno, CA)    29     7    16    ...        20     9     1
# 3  1275.20 (Los Angeles, CA)     4     0     4    ...         2     2     0
# 4     3109 (Los Angeles, CA)    15     0    12    ...        11     4     0
#
#    cd02  cd03  cd04  cs01  cs02  new value  new_value
# 0     2    30    10    16    34       49.2      -50.8
# ...

# %%
# use this method to replace dog back to cat

# %% [markdown]
# ## Pandas: Replacing values in a variable

# %%
df.head()
# Out:
#    year  st      stname   cty                 ctyname        trct  \
# 0    24   1     Alabama  1125   Tuscaloosa County, AL  1125012405
# 1    24   5    Arkansas  5083        Logan County, AR  5083950500
# 2  2018   6  California  6019       Fresno County, CA  6019005409
# 3  2017   6  California  6037  Los Angeles County, CA  6037127520
# 4  2014   6  California  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02    ...      ct01  ct02  cd01  \
# 0    124.05 (Tuscaloosa, AL)     0     8    34    ...        49     1     0
# 1           9505 (Logan, AR)    11     1     9    ...        11     0     1
# 2         54.09 (Fresno, CA)    29     7    16    ...        20     9     1
# 3  1275.20 (Los Angeles, CA)     4     0     4    ...         2     2     0
# 4     3109 (Los Angeles, CA)    15     0    12    ...        11     4     0
#
#    cd02  cd03  cd04  cs01  cs02  new value  new_value
# 0     2    30    10    16    34       49.2      -50.8
# ...

# %%
df.loc[df['year'] == 2011, 'year'] = 20

# %%
df.head()
# Out:
#    year  st      stname   cty                 ctyname        trct  \
# 0    24   1     Alabama  1125   Tuscaloosa County, AL  1125012405
# 1    24   5    Arkansas  5083        Logan County, AR  5083950500
# 2  2018   6  California  6019       Fresno County, CA  6019005409
# 3  2017   6  California  6037  Los Angeles County, CA  6037127520
# 4  2014   6  California  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02    ...      ct01  ct02  cd01  \
# 0    124.05 (Tuscaloosa, AL)     0     8    34    ...        49     1     0
# 1           9505 (Logan, AR)    11     1     9    ...        11     0     1
# 2         54.09 (Fresno, CA)    29     7    16    ...        20     9     1
# 3  1275.20 (Los Angeles, CA)     4     0     4    ...         2     2     0
# 4     3109 (Los Angeles, CA)    15     0    12    ...        11     4     0
#
#    cd02  cd03  cd04  cs01  cs02  new value  new_value
# 0     2    30    10    16    34       49.2      -50.8
# ...

# %% [markdown]
# ## Pandas: Renaming a variable

# %%
df = df.rename(columns={"year": "Year", "st": "State"})
df.head()
# Out:
#    Year  State      stname   cty                 ctyname        trct  \
# 0    24      1     Alabama  1125   Tuscaloosa County, AL  1125012405
# 1    24      5    Arkansas  5083        Logan County, AR  5083950500
# 2  2018      6  California  6019       Fresno County, CA  6019005409
# 3  2017      6  California  6037  Los Angeles County, CA  6037127520
# 4  2014      6  California  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02    ...      ct01  ct02  cd01  \
# 0    124.05 (Tuscaloosa, AL)     0     8    34    ...        49     1     0
# 1           9505 (Logan, AR)    11     1     9    ...        11     0     1
# 2         54.09 (Fresno, CA)    29     7    16    ...        20     9     1
# 3  1275.20 (Los Angeles, CA)     4     0     4    ...         2     2     0
# 4     3109 (Los Angeles, CA)    15     0    12    ...        11     4     0
#
#    cd02  cd03  cd04  cs01  cs02  new value  new_value
# ...

# %% [markdown]
# ## Pandas: Dropping a variable

# %%
df = df.drop("7", axis=1)
df.head()

# %% [markdown]
# ## General Python: Creating a function/functions in general

# %%
def function_example(x): 
    x = x + 1
    y = "cat"
    return x

# %% [markdown]
# ## Pandas: Creating a new column with a function (apply)

# %%
df.head()
# Out:
#    year  st      stname   cty                 ctyname        trct  \
# 0    20   1     Alabama  1125   Tuscaloosa County, AL  1125012405
# 1    20   5    Arkansas  5083        Logan County, AR  5083950500
# 2  2014   6  California  6019       Fresno County, CA  6019005409
# 3  2013   6  California  6037  Los Angeles County, CA  6037127520
# 4  2010   6  California  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02  ...   cr05  cr07  ct01  ct02  \
# 0    124.05 (Tuscaloosa, AL)    50     8    34  ...      0     1    49     1
# 1           9505 (Logan, AR)    11     1     9  ...      0     0    11     0
# 2         54.09 (Fresno, CA)    29     7    16  ...      0     7    20     9
# 3  1275.20 (Los Angeles, CA)     4     0     4  ...      0     2     2     2
# 4     3109 (Los Angeles, CA)    15     0    12  ...      0     0    11     4
#
#    cd01  cd02  cd03  cd04  cs01  cs02
# 0     0     2    30    10    16    34
# ...

# %%
df['year'] = df['year'].apply(function_example)
df.head()
# Out:
#    year  st      stname   cty                 ctyname        trct  \
# 0    21   1     Alabama  1125   Tuscaloosa County, AL  1125012405
# 1    21   5    Arkansas  5083        Logan County, AR  5083950500
# 2  2015   6  California  6019       Fresno County, CA  6019005409
# 3  2014   6  California  6037  Los Angeles County, CA  6037127520
# 4  2011   6  California  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02  ...   cr05  cr07  ct01  ct02  \
# 0    124.05 (Tuscaloosa, AL)    50     8    34  ...      0     1    49     1
# 1           9505 (Logan, AR)    11     1     9  ...      0     0    11     0
# 2         54.09 (Fresno, CA)    29     7    16  ...      0     7    20     9
# 3  1275.20 (Los Angeles, CA)     4     0     4  ...      0     2     2     2
# 4     3109 (Los Angeles, CA)    15     0    12  ...      0     0    11     4
#
#    cd01  cd02  cd03  cd04  cs01  cs02
# 0     0     2    30    10    16    34
# ...

# %% [markdown]
# ## Pandas: Creating a new column with a lambda function (apply)

# %%
df['year'] = df['year'].apply(lambda x: x + 1)
df.head()
# Out:
#    year  st      stname   cty                 ctyname        trct  \
# 0    24   1     Alabama  1125   Tuscaloosa County, AL  1125012405
# 1    24   5    Arkansas  5083        Logan County, AR  5083950500
# 2  2018   6  California  6019       Fresno County, CA  6019005409
# 3  2017   6  California  6037  Los Angeles County, CA  6037127520
# 4  2014   6  California  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02  ...   cr05  cr07  ct01  ct02  \
# 0    124.05 (Tuscaloosa, AL)    50     8    34  ...      0     1    49     1
# 1           9505 (Logan, AR)    11     1     9  ...      0     0    11     0
# 2         54.09 (Fresno, CA)    29     7    16  ...      0     7    20     9
# 3  1275.20 (Los Angeles, CA)     4     0     4  ...      0     2     2     2
# 4     3109 (Los Angeles, CA)    15     0    12  ...      0     0    11     4
#
#    cd01  cd02  cd03  cd04  cs01  cs02
# 0     0     2    30    10    16    34
# ...

# %%
df['stname'] = df['stname'].apply(lambda x: x[0:2])
df.head()
# Out:
#    Year  State stname   cty                 ctyname        trct  \
# 0    24      1     Al  1125   Tuscaloosa County, AL  1125012405
# 1    24      5     Ar  5083        Logan County, AR  5083950500
# 2  2018      6     Ca  6019       Fresno County, CA  6019005409
# 3  2017      6     Ca  6037  Los Angeles County, CA  6037127520
# 4  2014      6     Ca  6037  Los Angeles County, CA  6037310900
#
#                     trctname  c000  ca01  ca02    ...      ct01  ct02  cd01  \
# 0    124.05 (Tuscaloosa, AL)     0     8    34    ...        49     1     0
# 1           9505 (Logan, AR)    11     1     9    ...        11     0     1
# 2         54.09 (Fresno, CA)    29     7    16    ...        20     9     1
# 3  1275.20 (Los Angeles, CA)     4     0     4    ...         2     2     0
# 4     3109 (Los Angeles, CA)    15     0    12    ...        11     4     0
#
#    cd02  cd03  cd04  cs01  cs02  new value  new_value
# 0     2    30    10    16    34       49.2      -50.8
# ...

# %%
df['ctyname'] = df['ctyname'].apply(lambda x: x.replace(",", "--"))
df.head()
# Out:
#    Year  State stname   cty                  ctyname        trct  \
# 0    24      1     Al  1125   Tuscaloosa County-- AL  1125012405
# 1    24      5     Ar  5083        Logan County-- AR  5083950500
# 2  2018      6     Ca  6019       Fresno County-- CA  6019005409
# 3  2017      6     Ca  6037  Los Angeles County-- CA  6037127520
# 4  2014      6     Ca  6037  Los Angeles County-- CA  6037310900
#
#                     trctname  c000  ca01  ca02    ...      ct01  ct02  cd01  \
# 0    124.05 (Tuscaloosa, AL)     0     8    34    ...        49     1     0
# 1           9505 (Logan, AR)    11     1     9    ...        11     0     1
# 2         54.09 (Fresno, CA)    29     7    16    ...        20     9     1
# 3  1275.20 (Los Angeles, CA)     4     0     4    ...         2     2     0
# 4     3109 (Los Angeles, CA)    15     0    12    ...        11     4     0
#
#    cd02  cd03  cd04  cs01  cs02  new value  new_value
# 0     2    30    10    16    34       49.2      -50.8
# ...

# %% [markdown]
# ## Pandas: Appending

# %%
left_frame = pd.DataFrame({'key': range(5), 
                           'left_value': ['a', 'b', 'c', 'd', 'e']})
right_frame = pd.DataFrame({'key': range(2, 7), 
                           'right_value': ['f', 'g', 'h', 'i', 'j']})
print(left_frame)
print('\n')
print(right_frame)

# %%
pd.concat([left_frame, right_frame], sort='True')

# %% [markdown]
# ## Pandas: Merging

# %%
left_frame = pd.DataFrame({'key': range(5), 
                           'left_value': ['a', 'b', 'c', 'd', 'e']})
right_frame = pd.DataFrame({'key': range(2, 7), 
                           'right_value': ['f', 'g', 'h', 'i', 'j']})
print(left_frame)
print('\n')
print(right_frame)

# %%
pd.merge(left_frame, right_frame, on='key', how='inner')

# %%
pd.merge(left_frame, right_frame, on='key', how='left')

# %%
pd.merge(left_frame, right_frame, on='key', how='right')

# %% [markdown]
#  ## Pandas: dummy variables/factor variables

# %%
dummy = pd.get_dummies(df['stname'])
df = pd.concat([df, dummy], axis = 1)
df.head(10)

# %% [markdown]
# ## Pandas: Working w/ NA’s + fillNA

# %%
df.fillna(0).head()

# %% [markdown]
# ## Pandas: Group-By

# %%
# Groupby one column and return the mean of only particular column in the group.
avg_total_jobs_by_cty = va_dat.groupby(['ctyname', 'year'])['c000'].mean().reset_index()
avg_total_jobs_by_cty

# %% [markdown]
# ## Pandas: Reshaping Data – Wide to Long

# %%
df_ex = pd.DataFrame({
    'Unique Family Identifier': [1000, 1000, 1000, 1001, 1001, 1001, 1002, 324, 234],
    'Order': [1, 2, 3, 1, 2, 3, 1, 2, 3], 
    'az1': [28, 82, 23, 234, 234, 324, 546, 546, 5464],
    'az2': [2342, 2342, 54645, 56765, 65765, 65756, 3453, 56756, 3453]})
reshape = pd.wide_to_long(df_ex, stubnames='az', i=['Unique Family Identifier', 'Order'], j='age')

# %% [markdown]
# ## Pandas: Reshaping Data – Long to Wide

# %%
normal = reshape.unstack()
normal.columns = normal.columns.map('{0[0]}{0[1]}'.format)
normal.reset_index()
normal.head()
